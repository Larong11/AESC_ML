# %% [markdown]
# # ДЗ №1 СУНЦ МГУ - Numpy practice

# %% [markdown]
# _Задачи позаимствованы из курса ML ФКН ПМИ где они были позаимствованы из курса практикума кафедры ММП факультета ВМК МГУ_

# %% [markdown]
# ### Туториальные задачи
# __(9 баллов)__
#
# Ниже приведены задачи на работу с numpy-массивами. Для каждой из задач нужно привести 2 реализации: одна без использования numpy (cчитайте, что там, где на входе или выходе должны быть numpy array, будут просто списки), а вторая полностью векторизованная (без использования питоновских циклов/map/list comprehension). Невекторизованная реализация каждой из задач оценивается в __0.5 балла__, векторизованная – в __1 балл__.
#
# Реализации без использования векторизации нужно записать в файл functions.py, а векторизованные &mdash; в файл functions_vectorized.py
#
# Для каждой задачи, приведённой ниже сравните скорость работы невекторизованной и векторизованной реализации. С помощью пакета matplotlib постройте графики времени работы в зависимости от размера данных. __Графики должны выглядеть опрятно!__ То есть должны быть подписаны оси, названия графиков, и т.д. Например, ниже представлены хороший и плохой графики:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_size = np.array([10, 30, 70, 120])
time_non_vectorized = data_size ** 2 + 10
time_vectorized = data_size ** 1.5

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.plot(data_size, time_non_vectorized)
ax1.plot(data_size, time_vectorized)
ax1.set_title(u"Плохой график")
ax1.set_xlabel(u"Размер данных")
ax1.set_ylabel(u"Время")

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Хороший график")
ax2.set_xlabel(u"Длина массива")
ax2.set_ylabel(u"Время (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# /var/folders/p4/3ctvp9vd7x54_fdvd8d2xzl00000gn/T/ipykernel_3682/3107362156.py:26: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
# * __Задача 1__: Подсчитать произведение ненулевых элементов на диагонали прямоугольной матрицы.
#  Например, для X = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]]) ответ – 3.

# %%
# code here
import importlib
import functions
import functions_vectorized
import numpy as np
import matplotlib.pyplot as plt
import time
importlib.reload(functions)
importlib.reload(functions_vectorized)


data_size = np.array([1000])
for i in range(2000, 40001, 1000):
    data_size = np.append(data_size, i)
time_non_vectorized = np.zeros(len(data_size))
time_vectorized = np.zeros(len(data_size))

for i in range(0, len(data_size)):
    x = np.random.randint(100, size=(data_size[i], data_size[i]))

    t = time.time() * 1000
    functions.prod_non_zero_diag(x)
    time_non_vectorized[i] = time.time() * 1000 - t

    t = time.time() * 1000
    functions_vectorized.prod_non_zero_diag(x)
    time_vectorized[i] = time.time() * 1000 - t

f, ax2 = plt.subplots(1, 1, figsize=(13, 5))  # Create a single subplot

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Разница времени")
ax2.set_xlabel(u"Размер массива")
ax2.set_ylabel(u"Время (мс)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# /Users/larong/CLionProjects/AESC_ML/task#1/functions.py:6: RuntimeWarning: overflow encountered in scalar multiply
#   p *= x[i][i]
# /var/folders/p4/3ctvp9vd7x54_fdvd8d2xzl00000gn/T/ipykernel_3682/4153322224.py:39: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
#
#
# * __Задача 2__: Даны два вектора x и y. Проверить, задают ли они одно и то же мультимножество.
#   Например, для x = np.array([1, 2, 2, 4]), y = np.array([4, 2, 1, 2]) ответ – True.

# %%
# code here
import importlib
import functions
import functions_vectorized
import numpy as np
import matplotlib.pyplot as plt
import time
importlib.reload(functions)
importlib.reload(functions_vectorized)


data_size = np.array([1000])
for i in range(2000, 1000001, 100):
    data_size = np.append(data_size, i)
time_non_vectorized = np.zeros(len(data_size))
time_vectorized = np.zeros(len(data_size))

for i in range(0, len(data_size)):
    x = np.random.randint(100, size=data_size[i])
    y = np.random.randint(100, size=data_size[i])

    t = time.time() * 1000
    functions.are_multisets_equal(x, y)
    time_non_vectorized[i] = time.time() * 1000 - t

    t = time.time() * 1000
    functions_vectorized.are_multisets_equal(x, y)
    time_vectorized[i] = time.time() * 1000 - t

f, ax2 = plt.subplots(1, 1, figsize=(13, 5))  # Create a single subplot

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Разница времени")
ax2.set_xlabel(u"Размер массива")
ax2.set_ylabel(u"Время (мс)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# /var/folders/p4/3ctvp9vd7x54_fdvd8d2xzl00000gn/T/ipykernel_3849/1308611033.py:40: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
# * __Задача 3__: Найти максимальный элемент в векторе x среди элементов, перед которыми стоит нулевой.
#  Например, для x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) ответ – 5.

# %%
# code here
import importlib
import functions
import functions_vectorized
import numpy as np # type: ignore
import matplotlib.pyplot as plt
import time
importlib.reload(functions)
importlib.reload(functions_vectorized)


data_size = np.array([1000])
for i in range(2000, 1000001, 10000):
    data_size = np.append(data_size, i)
time_non_vectorized = np.zeros(len(data_size))
time_vectorized = np.zeros(len(data_size))

for i in range(0, len(data_size)):
    x = np.random.randint(100, size=data_size[i])

    t = time.time() * 1000
    functions.max_after_zero(x)
    time_non_vectorized[i] = time.time() * 1000 - t

    t = time.time() * 1000
    functions_vectorized.max_after_zero(x)
    time_vectorized[i] = time.time() * 1000 - t

f, ax2 = plt.subplots(1, 1, figsize=(13, 5))  # Create a single subplot

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Разница времени")
ax2.set_xlabel(u"Размер массива")
ax2.set_ylabel(u"Время (мс)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# /var/folders/p4/3ctvp9vd7x54_fdvd8d2xzl00000gn/T/ipykernel_3849/112928626.py:39: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
#
#
# * __ Задача 4__: Дан трёхмерный массив, содержащий изображение, размера (height, width, numChannels), а также вектор длины numChannels. Сложить каналы изображения с указанными весами, и вернуть результат в виде матрицы размера (height, width). В ноутбуке приведите пример работы функции – преобразуйте цветное изображение в оттенки серого, использовав коэффициенты np.array([0.299, 0.587, 0.114]). Считать реальное изображение можно при помощи функции scipy.misc.imread (если изображение не в формате png, установите пакет pillow).

# %%
import importlib
import functions
import functions_vectorized
import numpy as np
import matplotlib.pyplot as plt
import time
importlib.reload(functions)
importlib.reload(functions_vectorized)


data_size = np.array([1000])
for i in range(2000, 100001, 100):
    data_size = np.append(data_size, i)
time_non_vectorized = np.zeros(len(data_size))
time_vectorized = np.zeros(len(data_size))

for i in range(0, len(data_size)):
    x = np.random.randint(100, size=data_size[i])
    y = np.random.randint(100, size=data_size[i])

    t = time.time() * 1000
    functions.are_multisets_equal(x, y)
    time_non_vectorized[i] = time.time() * 1000 - t

    t = time.time() * 1000
    functions_vectorized.are_multisets_equal(x, y)
    time_vectorized[i] = time.time() * 1000 - t

f, ax2 = plt.subplots(1, 1, figsize=(13, 5))  # Create a single subplot

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Разница времени")
ax2.set_xlabel(u"Размер массива")
ax2.set_ylabel(u"Время (мс)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# /var/folders/p4/3ctvp9vd7x54_fdvd8d2xzl00000gn/T/ipykernel_3682/2306346436.py:39: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
# * __Задача 5__: Реализовать кодирование длин серий (Run-length encoding). Для некоторого вектора x необходимо вернуть кортеж из двух векторов одинаковой длины. Первый содержит числа, а второй - сколько раз их нужно повторить.
#  Например, для x = np.array([2, 2, 2, 3, 3, 3, 5]) ответ – (np.array([2, 3, 5]), np.array([3, 3, 1])).

# %%
# code here
import importlib
import functions
import functions_vectorized
import numpy as np # type: ignore
import matplotlib.pyplot as plt
import time
importlib.reload(functions)
importlib.reload(functions_vectorized)


data_size = np.array([1000])
for i in range(2000, 1000001, 10000):
    data_size = np.append(data_size, i)
time_non_vectorized = np.zeros(len(data_size))
time_vectorized = np.zeros(len(data_size))

for i in range(0, len(data_size)):
    x = np.random.randint(100, size=data_size[i])
    x.sort()

    t = time.time() * 1000
    functions.run_length_encoding(x)
    time_non_vectorized[i] = time.time() * 1000 - t

    t = time.time() * 1000
    functions_vectorized.run_length_encoding(x)
    time_vectorized[i] = time.time() * 1000 - t

f, ax2 = plt.subplots(1, 1, figsize=(13, 5))  # Create a single subplot

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Разница времени")
ax2.set_xlabel(u"Размер массива")
ax2.set_ylabel(u"Время (мс)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# /var/folders/p4/3ctvp9vd7x54_fdvd8d2xzl00000gn/T/ipykernel_3849/363430242.py:40: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
#
#
# * __Задача 6__: Даны две выборки объектов - X и Y. Вычислить матрицу евклидовых расстояний между объектами. Дополнительно сравните с функцией scipy.spatial.distance.cdist по скорости работы (сравнения приведите ниже в ноутбуке).

# %%
# code here

# %% [markdown]
# ### Туториал по Markdown
#
# __(1 балл)__
#
# Напишите краткий (а в данной домашке ещё и почти бесмысленный) отчёт с использованием 4-5 различных вариантов разметки/выделения текста.

# %%
# code here
